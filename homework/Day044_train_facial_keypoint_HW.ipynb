# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
 # %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
 import tensorflow as tf
 print(tf.__version__)

 import os
 from google.colab import drive 
 drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
 # %cd 'gdrive/My Drive/D44'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
 # %cd cupoy_cv_part4
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/D44
# /content/gdrive/My Drive/D44/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.4564e-05 - val_loss: 7.0272e-04
#
# Epoch 00001: val_loss improved from inf to 0.00070, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.4231e-05 - val_loss: 7.2547e-04
#
# Epoch 00002: val_loss did not improve from 0.00070
# Epoch 3/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.1376e-05 - val_loss: 7.1547e-04
#
# Epoch 00003: val_loss did not improve from 0.00070
# Epoch 4/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.1825e-05 - val_loss: 7.1139e-04
#
# Epoch 00004: val_loss did not improve from 0.00070
# Epoch 5/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 8.2347e-05 - val_loss: 7.2034e-04
#
# Epoch 00005: val_loss did not improve from 0.00070
# Epoch 6/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.2343e-05 - val_loss: 7.1853e-04
#
# Epoch 00006: val_loss did not improve from 0.00070
# Epoch 7/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.0581e-05 - val_loss: 6.9630e-04
#
# Epoch 00007: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 8.0024e-05 - val_loss: 7.2940e-04
#
# Epoch 00008: val_loss did not improve from 0.00070
# Epoch 9/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 7.9444e-05 - val_loss: 7.0365e-04
#
# Epoch 00009: val_loss did not improve from 0.00070
# Epoch 10/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.8962e-05 - val_loss: 6.9160e-04
#
# Epoch 00010: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 7.7256e-05 - val_loss: 6.8925e-04
#
# Epoch 00011: val_loss improved from 0.00069 to 0.00069, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 8.2825e-05 - val_loss: 6.9381e-04
#
# Epoch 00012: val_loss did not improve from 0.00069
# Epoch 13/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 7.7592e-05 - val_loss: 6.9000e-04
#
# Epoch 00013: val_loss did not improve from 0.00069
# Epoch 14/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 7.7698e-05 - val_loss: 6.8420e-04
#
# Epoch 00014: val_loss improved from 0.00069 to 0.00068, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 7.9132e-05 - val_loss: 7.1717e-04
#
# Epoch 00015: val_loss did not improve from 0.00068
# Epoch 16/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.6321e-05 - val_loss: 7.0237e-04
#
# Epoch 00016: val_loss did not improve from 0.00068
# Epoch 17/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 7.6622e-05 - val_loss: 6.8430e-04
#
# Epoch 00017: val_loss did not improve from 0.00068
# Epoch 18/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 7.6559e-05 - val_loss: 6.9803e-04
#
# Epoch 00018: val_loss did not improve from 0.00068
# Epoch 19/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 7.6101e-05 - val_loss: 6.9161e-04
#
# Epoch 00019: val_loss did not improve from 0.00068
# Epoch 20/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 7.6033e-05 - val_loss: 7.3251e-04
#
# Epoch 00020: val_loss did not improve from 0.00068
# Epoch 21/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 7.6113e-05 - val_loss: 7.2103e-04
#
# Epoch 00021: val_loss did not improve from 0.00068
# Epoch 22/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.5679e-05 - val_loss: 6.9269e-04
#
# Epoch 00022: val_loss did not improve from 0.00068
# Epoch 23/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 7.3680e-05 - val_loss: 6.9699e-04
#
# Epoch 00023: val_loss did not improve from 0.00068
# Epoch 24/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 7.4220e-05 - val_loss: 7.0030e-04
#
# Epoch 00024: val_loss did not improve from 0.00068
# Epoch 25/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.4598e-05 - val_loss: 7.2408e-04
#
# Epoch 00025: val_loss did not improve from 0.00068
# Epoch 26/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 7.3411e-05 - val_loss: 7.0473e-04
#
# Epoch 00026: val_loss did not improve from 0.00068
# Epoch 27/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 7.4123e-05 - val_loss: 7.2239e-04
#
# Epoch 00027: val_loss did not improve from 0.00068
# Epoch 28/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 7.2144e-05 - val_loss: 6.9935e-04
#
# Epoch 00028: val_loss did not improve from 0.00068
# Epoch 29/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.3568e-05 - val_loss: 7.2690e-04
#
# Epoch 00029: val_loss did not improve from 0.00068
# Epoch 30/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 7.1961e-05 - val_loss: 6.8976e-04
#
# Epoch 00030: val_loss did not improve from 0.00068
# Epoch 31/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 7.4423e-05 - val_loss: 7.1481e-04
#
# Epoch 00031: val_loss did not improve from 0.00068
# Epoch 32/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 7.4656e-05 - val_loss: 7.3860e-04
#
# Epoch 00032: val_loss did not improve from 0.00068
# Epoch 33/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.2583e-05 - val_loss: 6.9975e-04
#
# Epoch 00033: val_loss did not improve from 0.00068
# Epoch 34/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 7.1490e-05 - val_loss: 7.3091e-04
#
# Epoch 00034: val_loss did not improve from 0.00068
# Epoch 35/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 6.9650e-05 - val_loss: 6.9722e-04
#
# Epoch 00035: val_loss did not improve from 0.00068
# Epoch 36/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 7.1002e-05 - val_loss: 7.7441e-04
#
# Epoch 00036: val_loss did not improve from 0.00068
# Epoch 37/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 7.3909e-05 - val_loss: 7.0761e-04
#
# Epoch 00037: val_loss did not improve from 0.00068
# Epoch 38/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.2537e-05 - val_loss: 7.0781e-04
#
# Epoch 00038: val_loss did not improve from 0.00068
# Epoch 39/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 7.3630e-05 - val_loss: 7.1453e-04
#
# Epoch 00039: val_loss did not improve from 0.00068
# Epoch 40/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.3119e-05 - val_loss: 7.2018e-04
#
# Epoch 00040: val_loss did not improve from 0.00068
# Epoch 41/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 7.3203e-05 - val_loss: 7.3234e-04
#
# Epoch 00041: val_loss did not improve from 0.00068
# Epoch 42/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 7.5192e-05 - val_loss: 7.1293e-04
#
# Epoch 00042: val_loss did not improve from 0.00068
# Epoch 43/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 6.9937e-05 - val_loss: 7.1434e-04
#
# Epoch 00043: val_loss did not improve from 0.00068
# Epoch 44/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.9394e-05 - val_loss: 7.0952e-04
#
# Epoch 00044: val_loss did not improve from 0.00068
# Epoch 45/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.0559e-05 - val_loss: 6.8979e-04
#
# Epoch 00045: val_loss did not improve from 0.00068
# Epoch 46/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 7.0476e-05 - val_loss: 7.2167e-04
#
# Epoch 00046: val_loss did not improve from 0.00068
# Epoch 47/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 7.2157e-05 - val_loss: 7.1763e-04
#
# Epoch 00047: val_loss did not improve from 0.00068
# Epoch 48/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.0739e-05 - val_loss: 6.9517e-04
#
# Epoch 00048: val_loss did not improve from 0.00068
# Epoch 49/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.8516e-05 - val_loss: 7.1070e-04
#
# Epoch 00049: val_loss did not improve from 0.00068
# Epoch 50/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.0040e-05 - val_loss: 6.9939e-04
#
# Epoch 00050: val_loss did not improve from 0.00068
# Epoch 51/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.8404e-05 - val_loss: 7.0726e-04
#
# Epoch 00051: val_loss did not improve from 0.00068
# Epoch 52/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.7522e-05 - val_loss: 7.1428e-04
#
# Epoch 00052: val_loss did not improve from 0.00068
# Epoch 53/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.7485e-05 - val_loss: 7.1225e-04
#
# Epoch 00053: val_loss did not improve from 0.00068
# Epoch 54/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.7723e-05 - val_loss: 7.0402e-04
#
# Epoch 00054: val_loss did not improve from 0.00068
# Epoch 55/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.9952e-05 - val_loss: 6.9458e-04
#
# Epoch 00055: val_loss did not improve from 0.00068
# Epoch 56/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.7008e-05 - val_loss: 7.1329e-04
#
# Epoch 00056: val_loss did not improve from 0.00068
# Epoch 57/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.8098e-05 - val_loss: 7.1750e-04
#
# Epoch 00057: val_loss did not improve from 0.00068
# Epoch 58/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.8708e-05 - val_loss: 7.1621e-04
#
# Epoch 00058: val_loss did not improve from 0.00068
# Epoch 59/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.7422e-05 - val_loss: 6.8821e-04
#
# Epoch 00059: val_loss did not improve from 0.00068
# Epoch 60/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.7519e-05 - val_loss: 7.1319e-04
#
# Epoch 00060: val_loss did not improve from 0.00068
# Epoch 61/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.8646e-05 - val_loss: 7.0908e-04
#
# Epoch 00061: val_loss did not improve from 0.00068
# Epoch 62/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.8916e-05 - val_loss: 7.2108e-04
#
# Epoch 00062: val_loss did not improve from 0.00068
# Epoch 63/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.7404e-05 - val_loss: 6.9462e-04
#
# Epoch 00063: val_loss did not improve from 0.00068
# Epoch 64/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.8296e-05 - val_loss: 7.0485e-04
#
# Epoch 00064: val_loss did not improve from 0.00068
# Epoch 65/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.7145e-05 - val_loss: 7.0616e-04
#
# Epoch 00065: val_loss did not improve from 0.00068
# Epoch 66/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.5940e-05 - val_loss: 7.3629e-04
#
# Epoch 00066: val_loss did not improve from 0.00068
# Epoch 67/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.7578e-05 - val_loss: 7.1727e-04
#
# Epoch 00067: val_loss did not improve from 0.00068
# Epoch 68/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.5429e-05 - val_loss: 7.1366e-04
#
# Epoch 00068: val_loss did not improve from 0.00068
# Epoch 69/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.8449e-05 - val_loss: 7.4063e-04
#
# Epoch 00069: val_loss did not improve from 0.00068
# Epoch 70/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.9693e-05 - val_loss: 7.0839e-04
#
# Epoch 00070: val_loss did not improve from 0.00068
# Epoch 71/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.7049e-05 - val_loss: 7.2670e-04
#
# Epoch 00071: val_loss did not improve from 0.00068
# Epoch 72/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.8108e-05 - val_loss: 7.4535e-04
#
# Epoch 00072: val_loss did not improve from 0.00068
# Epoch 73/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.9809e-05 - val_loss: 6.6574e-04
#
# Epoch 00073: val_loss improved from 0.00068 to 0.00067, saving model to best_weights.h5
# Epoch 74/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 6.8198e-05 - val_loss: 7.1039e-04
#
# Epoch 00074: val_loss did not improve from 0.00067
# Epoch 75/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.7542e-05 - val_loss: 7.3189e-04
#
# Epoch 00075: val_loss did not improve from 0.00067
# Epoch 76/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.5666e-05 - val_loss: 7.1857e-04
#
# Epoch 00076: val_loss did not improve from 0.00067
# Epoch 77/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 7.0357e-05 - val_loss: 7.0590e-04
#
# Epoch 00077: val_loss did not improve from 0.00067
# Epoch 78/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.7801e-05 - val_loss: 7.0804e-04
#
# Epoch 00078: val_loss did not improve from 0.00067
# Epoch 79/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.8563e-05 - val_loss: 7.2853e-04
#
# Epoch 00079: val_loss did not improve from 0.00067
# Epoch 80/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.4931e-05 - val_loss: 7.0755e-04
#
# Epoch 00080: val_loss did not improve from 0.00067
# Epoch 81/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.5393e-05 - val_loss: 7.0870e-04
#
# Epoch 00081: val_loss did not improve from 0.00067
# Epoch 82/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.5168e-05 - val_loss: 7.2122e-04
#
# Epoch 00082: val_loss did not improve from 0.00067
# Epoch 83/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.5301e-05 - val_loss: 7.0516e-04
#
# Epoch 00083: val_loss did not improve from 0.00067
# Epoch 84/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.6666e-05 - val_loss: 6.9659e-04
#
# Epoch 00084: val_loss did not improve from 0.00067
# Epoch 85/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 6.4018e-05 - val_loss: 6.9811e-04
#
# Epoch 00085: val_loss did not improve from 0.00067
# Epoch 86/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.4097e-05 - val_loss: 7.0603e-04
#
# Epoch 00086: val_loss did not improve from 0.00067
# Epoch 87/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 6.4654e-05 - val_loss: 7.2702e-04
#
# Epoch 00087: val_loss did not improve from 0.00067
# Epoch 88/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.5918e-05 - val_loss: 6.9947e-04
#
# Epoch 00088: val_loss did not improve from 0.00067
# Epoch 89/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.5890e-05 - val_loss: 7.0947e-04
#
# Epoch 00089: val_loss did not improve from 0.00067
# Epoch 90/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.4843e-05 - val_loss: 6.8412e-04
#
# Epoch 00090: val_loss did not improve from 0.00067
# Epoch 91/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.2047e-05 - val_loss: 7.1617e-04
#
# Epoch 00091: val_loss did not improve from 0.00067
# Epoch 92/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.4449e-05 - val_loss: 7.0239e-04
#
# Epoch 00092: val_loss did not improve from 0.00067
# Epoch 93/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.5060e-05 - val_loss: 7.0690e-04
#
# Epoch 00093: val_loss did not improve from 0.00067
# Epoch 94/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.5970e-05 - val_loss: 7.3542e-04
#
# Epoch 00094: val_loss did not improve from 0.00067
# Epoch 95/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.7889e-05 - val_loss: 6.9929e-04
#
# Epoch 00095: val_loss did not improve from 0.00067
# Epoch 96/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 6.5262e-05 - val_loss: 6.9455e-04
#
# Epoch 00096: val_loss did not improve from 0.00067
# Epoch 97/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.3380e-05 - val_loss: 7.0947e-04
#
# Epoch 00097: val_loss did not improve from 0.00067
# Epoch 98/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.3025e-05 - val_loss: 7.3452e-04
#
# Epoch 00098: val_loss did not improve from 0.00067
# Epoch 99/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 6.2991e-05 - val_loss: 7.2907e-04
#
# Epoch 00099: val_loss did not improve from 0.00067
# Epoch 100/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.2765e-05 - val_loss: 6.9525e-04
#
# Epoch 00100: val_loss did not improve from 0.00067
# Epoch 101/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.3157e-05 - val_loss: 7.0762e-04
#
# Epoch 00101: val_loss did not improve from 0.00067
# Epoch 102/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.2615e-05 - val_loss: 7.0371e-04
#
# Epoch 00102: val_loss did not improve from 0.00067
# Epoch 103/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.3038e-05 - val_loss: 7.3472e-04
#
# Epoch 00103: val_loss did not improve from 0.00067
# Epoch 104/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.2254e-05 - val_loss: 7.4430e-04
#
# Epoch 00104: val_loss did not improve from 0.00067
# Epoch 105/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.3323e-05 - val_loss: 7.3947e-04
#
# Epoch 00105: val_loss did not improve from 0.00067
# Epoch 106/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.1321e-05 - val_loss: 6.8787e-04
#
# Epoch 00106: val_loss did not improve from 0.00067
# Epoch 107/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.5603e-05 - val_loss: 7.3887e-04
#
# Epoch 00107: val_loss did not improve from 0.00067
# Epoch 108/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.7070e-05 - val_loss: 7.2386e-04
#
# Epoch 00108: val_loss did not improve from 0.00067
# Epoch 109/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 6.3321e-05 - val_loss: 7.1431e-04
#
# Epoch 00109: val_loss did not improve from 0.00067
# Epoch 110/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.3443e-05 - val_loss: 7.1988e-04
#
# Epoch 00110: val_loss did not improve from 0.00067
# Epoch 111/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 6.4742e-05 - val_loss: 6.9625e-04
#
# Epoch 00111: val_loss did not improve from 0.00067
# Epoch 112/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.6535e-05 - val_loss: 7.4242e-04
#
# Epoch 00112: val_loss did not improve from 0.00067
# Epoch 113/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.3005e-05 - val_loss: 7.0553e-04
#
# Epoch 00113: val_loss did not improve from 0.00067
# Epoch 114/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.1302e-05 - val_loss: 7.2777e-04
#
# Epoch 00114: val_loss did not improve from 0.00067
# Epoch 115/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.1231e-05 - val_loss: 7.1862e-04
#
# Epoch 00115: val_loss did not improve from 0.00067
# Epoch 116/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 6.2469e-05 - val_loss: 7.0726e-04
#
# Epoch 00116: val_loss did not improve from 0.00067
# Epoch 117/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0954e-05 - val_loss: 7.0484e-04
#
# Epoch 00117: val_loss did not improve from 0.00067
# Epoch 118/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.2067e-05 - val_loss: 7.2540e-04
#
# Epoch 00118: val_loss did not improve from 0.00067
# Epoch 119/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.2374e-05 - val_loss: 7.0327e-04
#
# Epoch 00119: val_loss did not improve from 0.00067
# Epoch 120/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.1972e-05 - val_loss: 7.2355e-04
#
# Epoch 00120: val_loss did not improve from 0.00067
# Epoch 121/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 6.2279e-05 - val_loss: 7.3362e-04
#
# Epoch 00121: val_loss did not improve from 0.00067
# Epoch 122/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 5.9445e-05 - val_loss: 7.0214e-04
#
# Epoch 00122: val_loss did not improve from 0.00067
# Epoch 123/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 6.0035e-05 - val_loss: 7.1697e-04
#
# Epoch 00123: val_loss did not improve from 0.00067
# Epoch 124/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 5.9673e-05 - val_loss: 7.2668e-04
#
# Epoch 00124: val_loss did not improve from 0.00067
# Epoch 125/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 5.9517e-05 - val_loss: 7.1822e-04
#
# Epoch 00125: val_loss did not improve from 0.00067
# Epoch 126/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 5.9437e-05 - val_loss: 7.2765e-04
#
# Epoch 00126: val_loss did not improve from 0.00067
# Epoch 127/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 5.9321e-05 - val_loss: 7.0939e-04
#
# Epoch 00127: val_loss did not improve from 0.00067
# Epoch 128/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 5.9063e-05 - val_loss: 7.2404e-04
#
# Epoch 00128: val_loss did not improve from 0.00067
# Epoch 129/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0499e-05 - val_loss: 7.2368e-04
#
# Epoch 00129: val_loss did not improve from 0.00067
# Epoch 130/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0958e-05 - val_loss: 7.6177e-04
#
# Epoch 00130: val_loss did not improve from 0.00067
# Epoch 131/150
# 1712/1712 [==============================] - 0s 159us/step - loss: 5.9423e-05 - val_loss: 7.2943e-04
#
# Epoch 00131: val_loss did not improve from 0.00067
# Epoch 132/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 6.2213e-05 - val_loss: 7.4471e-04
#
# Epoch 00132: val_loss did not improve from 0.00067
# Epoch 133/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.0339e-05 - val_loss: 7.3920e-04
#
# Epoch 00133: val_loss did not improve from 0.00067
# Epoch 134/150
# 1712/1712 [==============================] - 0s 160us/step - loss: 5.7581e-05 - val_loss: 7.3055e-04
#
# Epoch 00134: val_loss did not improve from 0.00067
# Epoch 135/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 5.8418e-05 - val_loss: 7.2423e-04
#
# Epoch 00135: val_loss did not improve from 0.00067
# Epoch 136/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 5.6657e-05 - val_loss: 7.1705e-04
#
# Epoch 00136: val_loss did not improve from 0.00067
# Epoch 137/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 5.9488e-05 - val_loss: 7.2627e-04
#
# Epoch 00137: val_loss did not improve from 0.00067
# Epoch 138/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.2154e-05 - val_loss: 7.0679e-04
#
# Epoch 00138: val_loss did not improve from 0.00067
# Epoch 139/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0507e-05 - val_loss: 7.3026e-04
#
# Epoch 00139: val_loss did not improve from 0.00067
# Epoch 140/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0511e-05 - val_loss: 7.4615e-04
#
# Epoch 00140: val_loss did not improve from 0.00067
# Epoch 141/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 6.0303e-05 - val_loss: 7.2026e-04
#
# Epoch 00141: val_loss did not improve from 0.00067
# Epoch 142/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.0634e-05 - val_loss: 7.2301e-04
#
# Epoch 00142: val_loss did not improve from 0.00067
# Epoch 143/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 5.8653e-05 - val_loss: 7.1505e-04
#
# Epoch 00143: val_loss did not improve from 0.00067
# Epoch 144/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 5.8025e-05 - val_loss: 7.6272e-04
#
# Epoch 00144: val_loss did not improve from 0.00067
# Epoch 145/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 6.0016e-05 - val_loss: 7.1862e-04
#
# Epoch 00145: val_loss did not improve from 0.00067
# Epoch 146/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 5.9295e-05 - val_loss: 7.4372e-04
#
# Epoch 00146: val_loss did not improve from 0.00067
# Epoch 147/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 6.0443e-05 - val_loss: 7.1987e-04
#
# Epoch 00147: val_loss did not improve from 0.00067
# Epoch 148/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 5.8774e-05 - val_loss: 7.4743e-04
#
# Epoch 00148: val_loss did not improve from 0.00067
# Epoch 149/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 5.8227e-05 - val_loss: 7.2729e-04
#
# Epoch 00149: val_loss did not improve from 0.00067
# Epoch 150/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 5.7161e-05 - val_loss: 7.4841e-04
#
# Epoch 00150: val_loss did not improve from 0.00067

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
train_datagen = ImageDataGenerator(rescale = 1./255,horizontal_flip = True)

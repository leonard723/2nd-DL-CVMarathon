# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
 # %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
 import tensorflow as tf
 print(tf.__version__)

 import os
 from google.colab import drive 
 drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
 # %cd 'gdrive/My Drive/D44'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
 # %cd cupoy_cv_part4
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/D44
# /content/gdrive/My Drive/D44/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0063 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00220, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00220 to 0.00193, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00187, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00187
# Epoch 6/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 9.7468e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00187 to 0.00179, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.1056e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00179 to 0.00155, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 7.1251e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00155 to 0.00141, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 6.3040e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00141 to 0.00126, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 5.6395e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00126 to 0.00116, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 5.1736e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00116 to 0.00114, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 4.7876e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00114 to 0.00109, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 4.3002e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00109 to 0.00106, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 4.1351e-04 - val_loss: 9.7557e-04
#
# Epoch 00014: val_loss improved from 0.00106 to 0.00098, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 3.8896e-04 - val_loss: 9.4167e-04
#
# Epoch 00015: val_loss improved from 0.00098 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 3.7876e-04 - val_loss: 9.1028e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 3.5908e-04 - val_loss: 8.9507e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 3.4338e-04 - val_loss: 9.6666e-04
#
# Epoch 00018: val_loss did not improve from 0.00090
# Epoch 19/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 3.2433e-04 - val_loss: 8.7996e-04
#
# Epoch 00019: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 3.1592e-04 - val_loss: 8.4066e-04
#
# Epoch 00020: val_loss improved from 0.00088 to 0.00084, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 3.0364e-04 - val_loss: 8.6674e-04
#
# Epoch 00021: val_loss did not improve from 0.00084
# Epoch 22/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.8874e-04 - val_loss: 8.9787e-04
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.8789e-04 - val_loss: 8.4164e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.8285e-04 - val_loss: 8.4276e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 2.7073e-04 - val_loss: 8.7905e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 2.6164e-04 - val_loss: 8.4535e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 2.4994e-04 - val_loss: 8.1391e-04
#
# Epoch 00027: val_loss improved from 0.00084 to 0.00081, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 2.5132e-04 - val_loss: 8.1995e-04
#
# Epoch 00028: val_loss did not improve from 0.00081
# Epoch 29/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.4553e-04 - val_loss: 8.3369e-04
#
# Epoch 00029: val_loss did not improve from 0.00081
# Epoch 30/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 2.5419e-04 - val_loss: 8.0565e-04
#
# Epoch 00030: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 2.3405e-04 - val_loss: 7.9719e-04
#
# Epoch 00031: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 2.2073e-04 - val_loss: 7.8721e-04
#
# Epoch 00032: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 2.1673e-04 - val_loss: 7.8035e-04
#
# Epoch 00033: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 2.2030e-04 - val_loss: 7.9032e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 2.1093e-04 - val_loss: 8.1182e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 2.0852e-04 - val_loss: 8.3372e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 2.0671e-04 - val_loss: 7.8578e-04
#
# Epoch 00037: val_loss did not improve from 0.00078
# Epoch 38/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 2.1227e-04 - val_loss: 7.9099e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 2.1108e-04 - val_loss: 8.1289e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.9791e-04 - val_loss: 7.8493e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.9446e-04 - val_loss: 7.8447e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.9532e-04 - val_loss: 7.9861e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.8802e-04 - val_loss: 7.5812e-04
#
# Epoch 00043: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.8551e-04 - val_loss: 7.6921e-04
#
# Epoch 00044: val_loss did not improve from 0.00076
# Epoch 45/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.7764e-04 - val_loss: 7.7626e-04
#
# Epoch 00045: val_loss did not improve from 0.00076
# Epoch 46/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.8206e-04 - val_loss: 7.7033e-04
#
# Epoch 00046: val_loss did not improve from 0.00076
# Epoch 47/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.7850e-04 - val_loss: 7.8919e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.7606e-04 - val_loss: 7.6375e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.7071e-04 - val_loss: 7.8604e-04
#
# Epoch 00049: val_loss did not improve from 0.00076
# Epoch 50/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.7142e-04 - val_loss: 7.6450e-04
#
# Epoch 00050: val_loss did not improve from 0.00076
# Epoch 51/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.6805e-04 - val_loss: 7.6292e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.6644e-04 - val_loss: 7.5287e-04
#
# Epoch 00052: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.6890e-04 - val_loss: 7.5675e-04
#
# Epoch 00053: val_loss did not improve from 0.00075
# Epoch 54/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.6237e-04 - val_loss: 8.1891e-04
#
# Epoch 00054: val_loss did not improve from 0.00075
# Epoch 55/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.7430e-04 - val_loss: 7.6614e-04
#
# Epoch 00055: val_loss did not improve from 0.00075
# Epoch 56/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.6465e-04 - val_loss: 7.8083e-04
#
# Epoch 00056: val_loss did not improve from 0.00075
# Epoch 57/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.5442e-04 - val_loss: 7.4868e-04
#
# Epoch 00057: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.5889e-04 - val_loss: 8.2063e-04
#
# Epoch 00058: val_loss did not improve from 0.00075
# Epoch 59/150
# 1712/1712 [==============================] - 0s 161us/step - loss: 1.5447e-04 - val_loss: 7.4600e-04
#
# Epoch 00059: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.5854e-04 - val_loss: 7.6531e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.5178e-04 - val_loss: 7.8279e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.5147e-04 - val_loss: 7.8680e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.4876e-04 - val_loss: 7.6646e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.5227e-04 - val_loss: 7.8274e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.4311e-04 - val_loss: 7.5772e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 1.4063e-04 - val_loss: 7.4489e-04
#
# Epoch 00066: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 67/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.3829e-04 - val_loss: 7.8032e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.4278e-04 - val_loss: 7.4465e-04
#
# Epoch 00068: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 69/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.4649e-04 - val_loss: 7.4818e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.4069e-04 - val_loss: 7.6964e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.3606e-04 - val_loss: 7.3772e-04
#
# Epoch 00071: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 72/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.3916e-04 - val_loss: 7.1579e-04
#
# Epoch 00072: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 73/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.3115e-04 - val_loss: 7.4170e-04
#
# Epoch 00073: val_loss did not improve from 0.00072
# Epoch 74/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.3356e-04 - val_loss: 7.7789e-04
#
# Epoch 00074: val_loss did not improve from 0.00072
# Epoch 75/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.3618e-04 - val_loss: 8.0368e-04
#
# Epoch 00075: val_loss did not improve from 0.00072
# Epoch 76/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.3449e-04 - val_loss: 7.7685e-04
#
# Epoch 00076: val_loss did not improve from 0.00072
# Epoch 77/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.3088e-04 - val_loss: 7.7386e-04
#
# Epoch 00077: val_loss did not improve from 0.00072
# Epoch 78/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.3687e-04 - val_loss: 7.5566e-04
#
# Epoch 00078: val_loss did not improve from 0.00072
# Epoch 79/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.3151e-04 - val_loss: 7.3861e-04
#
# Epoch 00079: val_loss did not improve from 0.00072
# Epoch 80/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.2853e-04 - val_loss: 7.6084e-04
#
# Epoch 00080: val_loss did not improve from 0.00072
# Epoch 81/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2849e-04 - val_loss: 7.9267e-04
#
# Epoch 00081: val_loss did not improve from 0.00072
# Epoch 82/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.2558e-04 - val_loss: 7.3396e-04
#
# Epoch 00082: val_loss did not improve from 0.00072
# Epoch 83/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2754e-04 - val_loss: 7.6226e-04
#
# Epoch 00083: val_loss did not improve from 0.00072
# Epoch 84/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.2425e-04 - val_loss: 7.4161e-04
#
# Epoch 00084: val_loss did not improve from 0.00072
# Epoch 85/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 1.2481e-04 - val_loss: 7.8422e-04
#
# Epoch 00085: val_loss did not improve from 0.00072
# Epoch 86/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.2571e-04 - val_loss: 7.9813e-04
#
# Epoch 00086: val_loss did not improve from 0.00072
# Epoch 87/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.2029e-04 - val_loss: 7.6407e-04
#
# Epoch 00087: val_loss did not improve from 0.00072
# Epoch 88/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1733e-04 - val_loss: 8.0361e-04
#
# Epoch 00088: val_loss did not improve from 0.00072
# Epoch 89/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.1945e-04 - val_loss: 7.9453e-04
#
# Epoch 00089: val_loss did not improve from 0.00072
# Epoch 90/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.2262e-04 - val_loss: 7.6171e-04
#
# Epoch 00090: val_loss did not improve from 0.00072
# Epoch 91/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.1722e-04 - val_loss: 7.2938e-04
#
# Epoch 00091: val_loss did not improve from 0.00072
# Epoch 92/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.1349e-04 - val_loss: 7.7135e-04
#
# Epoch 00092: val_loss did not improve from 0.00072
# Epoch 93/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1365e-04 - val_loss: 7.7202e-04
#
# Epoch 00093: val_loss did not improve from 0.00072
# Epoch 94/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1176e-04 - val_loss: 7.2932e-04
#
# Epoch 00094: val_loss did not improve from 0.00072
# Epoch 95/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.1499e-04 - val_loss: 7.3844e-04
#
# Epoch 00095: val_loss did not improve from 0.00072
# Epoch 96/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.1239e-04 - val_loss: 7.2989e-04
#
# Epoch 00096: val_loss did not improve from 0.00072
# Epoch 97/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 1.1086e-04 - val_loss: 7.6123e-04
#
# Epoch 00097: val_loss did not improve from 0.00072
# Epoch 98/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.1719e-04 - val_loss: 8.0511e-04
#
# Epoch 00098: val_loss did not improve from 0.00072
# Epoch 99/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.1351e-04 - val_loss: 7.5497e-04
#
# Epoch 00099: val_loss did not improve from 0.00072
# Epoch 100/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.1084e-04 - val_loss: 7.3758e-04
#
# Epoch 00100: val_loss did not improve from 0.00072
# Epoch 101/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0831e-04 - val_loss: 7.4553e-04
#
# Epoch 00101: val_loss did not improve from 0.00072
# Epoch 102/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.0900e-04 - val_loss: 7.6189e-04
#
# Epoch 00102: val_loss did not improve from 0.00072
# Epoch 103/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 1.0405e-04 - val_loss: 7.6107e-04
#
# Epoch 00103: val_loss did not improve from 0.00072
# Epoch 104/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 1.0781e-04 - val_loss: 7.5422e-04
#
# Epoch 00104: val_loss did not improve from 0.00072
# Epoch 105/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 1.0457e-04 - val_loss: 7.9637e-04
#
# Epoch 00105: val_loss did not improve from 0.00072
# Epoch 106/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 1.0760e-04 - val_loss: 7.4329e-04
#
# Epoch 00106: val_loss did not improve from 0.00072
# Epoch 107/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0418e-04 - val_loss: 7.7424e-04
#
# Epoch 00107: val_loss did not improve from 0.00072
# Epoch 108/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.0239e-04 - val_loss: 7.3962e-04
#
# Epoch 00108: val_loss did not improve from 0.00072
# Epoch 109/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 1.0418e-04 - val_loss: 7.7884e-04
#
# Epoch 00109: val_loss did not improve from 0.00072
# Epoch 110/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.0628e-04 - val_loss: 7.5588e-04
#
# Epoch 00110: val_loss did not improve from 0.00072
# Epoch 111/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.0428e-04 - val_loss: 7.5619e-04
#
# Epoch 00111: val_loss did not improve from 0.00072
# Epoch 112/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 1.0622e-04 - val_loss: 7.5417e-04
#
# Epoch 00112: val_loss did not improve from 0.00072
# Epoch 113/150
# 1712/1712 [==============================] - 0s 170us/step - loss: 1.0488e-04 - val_loss: 7.6350e-04
#
# Epoch 00113: val_loss did not improve from 0.00072
# Epoch 114/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.0186e-04 - val_loss: 7.4923e-04
#
# Epoch 00114: val_loss did not improve from 0.00072
# Epoch 115/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 9.9604e-05 - val_loss: 7.6296e-04
#
# Epoch 00115: val_loss did not improve from 0.00072
# Epoch 116/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.9105e-05 - val_loss: 7.4505e-04
#
# Epoch 00116: val_loss did not improve from 0.00072
# Epoch 117/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 9.9481e-05 - val_loss: 7.4389e-04
#
# Epoch 00117: val_loss did not improve from 0.00072
# Epoch 118/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 1.0078e-04 - val_loss: 7.4773e-04
#
# Epoch 00118: val_loss did not improve from 0.00072
# Epoch 119/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.7316e-05 - val_loss: 7.6626e-04
#
# Epoch 00119: val_loss did not improve from 0.00072
# Epoch 120/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.4683e-05 - val_loss: 7.9343e-04
#
# Epoch 00120: val_loss did not improve from 0.00072
# Epoch 121/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 1.0104e-04 - val_loss: 7.9022e-04
#
# Epoch 00121: val_loss did not improve from 0.00072
# Epoch 122/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.5664e-05 - val_loss: 7.2433e-04
#
# Epoch 00122: val_loss did not improve from 0.00072
# Epoch 123/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.8166e-05 - val_loss: 7.6370e-04
#
# Epoch 00123: val_loss did not improve from 0.00072
# Epoch 124/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.8589e-05 - val_loss: 7.5492e-04
#
# Epoch 00124: val_loss did not improve from 0.00072
# Epoch 125/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.9210e-05 - val_loss: 8.0130e-04
#
# Epoch 00125: val_loss did not improve from 0.00072
# Epoch 126/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 9.3679e-05 - val_loss: 7.6347e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 9.2169e-05 - val_loss: 7.7193e-04
#
# Epoch 00127: val_loss did not improve from 0.00072
# Epoch 128/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 9.4257e-05 - val_loss: 7.6508e-04
#
# Epoch 00128: val_loss did not improve from 0.00072
# Epoch 129/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 9.1135e-05 - val_loss: 7.9525e-04
#
# Epoch 00129: val_loss did not improve from 0.00072
# Epoch 130/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 9.1710e-05 - val_loss: 7.4855e-04
#
# Epoch 00130: val_loss did not improve from 0.00072
# Epoch 131/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 8.9746e-05 - val_loss: 7.5186e-04
#
# Epoch 00131: val_loss did not improve from 0.00072
# Epoch 132/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.8431e-05 - val_loss: 7.5622e-04
#
# Epoch 00132: val_loss did not improve from 0.00072
# Epoch 133/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.8374e-05 - val_loss: 7.9658e-04
#
# Epoch 00133: val_loss did not improve from 0.00072
# Epoch 134/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 8.7088e-05 - val_loss: 7.6117e-04
#
# Epoch 00134: val_loss did not improve from 0.00072
# Epoch 135/150
# 1712/1712 [==============================] - 0s 164us/step - loss: 8.8188e-05 - val_loss: 7.6646e-04
#
# Epoch 00135: val_loss did not improve from 0.00072
# Epoch 136/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.6700e-05 - val_loss: 7.6100e-04
#
# Epoch 00136: val_loss did not improve from 0.00072
# Epoch 137/150
# 1712/1712 [==============================] - 0s 163us/step - loss: 8.7326e-05 - val_loss: 7.5251e-04
#
# Epoch 00137: val_loss did not improve from 0.00072
# Epoch 138/150
# 1712/1712 [==============================] - 0s 165us/step - loss: 8.6916e-05 - val_loss: 7.5311e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.6702e-05 - val_loss: 7.6022e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.4945e-05 - val_loss: 7.5330e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.4835e-05 - val_loss: 7.7407e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.3825e-05 - val_loss: 7.8964e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.3982e-05 - val_loss: 7.4973e-04
#
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 8.4748e-05 - val_loss: 7.5686e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 0s 169us/step - loss: 8.4268e-05 - val_loss: 7.4855e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 0s 162us/step - loss: 8.2459e-05 - val_loss: 7.4796e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 0s 167us/step - loss: 8.4770e-05 - val_loss: 7.6457e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 0s 171us/step - loss: 8.1595e-05 - val_loss: 7.5287e-04
#
# Epoch 00148: val_loss did not improve from 0.00072
# Epoch 149/150
# 1712/1712 [==============================] - 0s 168us/step - loss: 8.2226e-05 - val_loss: 7.5899e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 0s 166us/step - loss: 8.2644e-05 - val_loss: 7.7644e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 269us/step - loss: 0.0048 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00195, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00195 to 0.00186, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00186 to 0.00176, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 8.9005e-04 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00176 to 0.00152, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 7.1229e-04 - val_loss: 0.0013
#
# Epoch 00005: val_loss improved from 0.00152 to 0.00127, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 5.9619e-04 - val_loss: 0.0012
#
# Epoch 00006: val_loss improved from 0.00127 to 0.00115, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 5.2312e-04 - val_loss: 0.0010
#
# Epoch 00007: val_loss improved from 0.00115 to 0.00103, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 4.8365e-04 - val_loss: 9.5346e-04
#
# Epoch 00008: val_loss improved from 0.00103 to 0.00095, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 4.3352e-04 - val_loss: 9.6809e-04
#
# Epoch 00009: val_loss did not improve from 0.00095
# Epoch 10/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 4.0429e-04 - val_loss: 8.9999e-04
#
# Epoch 00010: val_loss improved from 0.00095 to 0.00090, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 3.8293e-04 - val_loss: 8.2702e-04
#
# Epoch 00011: val_loss improved from 0.00090 to 0.00083, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 3.5958e-04 - val_loss: 8.1273e-04
#
# Epoch 00012: val_loss improved from 0.00083 to 0.00081, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 3.4535e-04 - val_loss: 7.8662e-04
#
# Epoch 00013: val_loss improved from 0.00081 to 0.00079, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 3.2482e-04 - val_loss: 8.0950e-04
#
# Epoch 00014: val_loss did not improve from 0.00079
# Epoch 15/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 3.1317e-04 - val_loss: 7.8430e-04
#
# Epoch 00015: val_loss improved from 0.00079 to 0.00078, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 3.0235e-04 - val_loss: 7.7442e-04
#
# Epoch 00016: val_loss improved from 0.00078 to 0.00077, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 2.8173e-04 - val_loss: 8.0160e-04
#
# Epoch 00017: val_loss did not improve from 0.00077
# Epoch 18/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 2.7915e-04 - val_loss: 7.2901e-04
#
# Epoch 00018: val_loss improved from 0.00077 to 0.00073, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 2.7352e-04 - val_loss: 7.9408e-04
#
# Epoch 00019: val_loss did not improve from 0.00073
# Epoch 20/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 2.6300e-04 - val_loss: 7.6695e-04
#
# Epoch 00020: val_loss did not improve from 0.00073
# Epoch 21/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 2.5497e-04 - val_loss: 7.3700e-04
#
# Epoch 00021: val_loss did not improve from 0.00073
# Epoch 22/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 2.5198e-04 - val_loss: 7.6674e-04
#
# Epoch 00022: val_loss did not improve from 0.00073
# Epoch 23/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 2.3925e-04 - val_loss: 7.1572e-04
#
# Epoch 00023: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 2.3365e-04 - val_loss: 6.8295e-04
#
# Epoch 00024: val_loss improved from 0.00072 to 0.00068, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 2.3370e-04 - val_loss: 7.1723e-04
#
# Epoch 00025: val_loss did not improve from 0.00068
# Epoch 26/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 2.2419e-04 - val_loss: 6.9350e-04
#
# Epoch 00026: val_loss did not improve from 0.00068
# Epoch 27/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 2.1715e-04 - val_loss: 7.1943e-04
#
# Epoch 00027: val_loss did not improve from 0.00068
# Epoch 28/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 2.1223e-04 - val_loss: 6.8975e-04
#
# Epoch 00028: val_loss did not improve from 0.00068
# Epoch 29/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 2.0505e-04 - val_loss: 6.5429e-04
#
# Epoch 00029: val_loss improved from 0.00068 to 0.00065, saving model to best_weights_augment.h5
# Epoch 30/150
# 3424/3424 [==============================] - 1s 178us/step - loss: 2.0277e-04 - val_loss: 6.8971e-04
#
# Epoch 00030: val_loss did not improve from 0.00065
# Epoch 31/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 2.0300e-04 - val_loss: 6.9312e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 1.9716e-04 - val_loss: 6.8446e-04
#
# Epoch 00032: val_loss did not improve from 0.00065
# Epoch 33/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.9571e-04 - val_loss: 6.8750e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.8977e-04 - val_loss: 6.4462e-04
#
# Epoch 00034: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.8842e-04 - val_loss: 6.9906e-04
#
# Epoch 00035: val_loss did not improve from 0.00064
# Epoch 36/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.8278e-04 - val_loss: 6.6816e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.7914e-04 - val_loss: 6.7242e-04
#
# Epoch 00037: val_loss did not improve from 0.00064
# Epoch 38/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.7556e-04 - val_loss: 6.5880e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.7213e-04 - val_loss: 6.6742e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.6796e-04 - val_loss: 6.6714e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.6448e-04 - val_loss: 6.6153e-04
#
# Epoch 00041: val_loss did not improve from 0.00064
# Epoch 42/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.6588e-04 - val_loss: 6.9739e-04
#
# Epoch 00042: val_loss did not improve from 0.00064
# Epoch 43/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.6630e-04 - val_loss: 6.8714e-04
#
# Epoch 00043: val_loss did not improve from 0.00064
# Epoch 44/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.5943e-04 - val_loss: 6.9900e-04
#
# Epoch 00044: val_loss did not improve from 0.00064
# Epoch 45/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.5845e-04 - val_loss: 7.0988e-04
#
# Epoch 00045: val_loss did not improve from 0.00064
# Epoch 46/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.5755e-04 - val_loss: 6.3985e-04
#
# Epoch 00046: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 47/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.5259e-04 - val_loss: 6.3259e-04
#
# Epoch 00047: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 48/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.5558e-04 - val_loss: 6.3159e-04
#
# Epoch 00048: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 49/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.5525e-04 - val_loss: 6.7110e-04
#
# Epoch 00049: val_loss did not improve from 0.00063
# Epoch 50/150
# 3424/3424 [==============================] - 1s 174us/step - loss: 1.4685e-04 - val_loss: 6.4327e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.4383e-04 - val_loss: 6.4205e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 1.4186e-04 - val_loss: 6.6582e-04
#
# Epoch 00052: val_loss did not improve from 0.00063
# Epoch 53/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.3949e-04 - val_loss: 6.7634e-04
#
# Epoch 00053: val_loss did not improve from 0.00063
# Epoch 54/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.3979e-04 - val_loss: 6.5589e-04
#
# Epoch 00054: val_loss did not improve from 0.00063
# Epoch 55/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.3985e-04 - val_loss: 6.7521e-04
#
# Epoch 00055: val_loss did not improve from 0.00063
# Epoch 56/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 1.3518e-04 - val_loss: 6.4112e-04
#
# Epoch 00056: val_loss did not improve from 0.00063
# Epoch 57/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.3482e-04 - val_loss: 6.5668e-04
#
# Epoch 00057: val_loss did not improve from 0.00063
# Epoch 58/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.3345e-04 - val_loss: 6.4851e-04
#
# Epoch 00058: val_loss did not improve from 0.00063
# Epoch 59/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.3076e-04 - val_loss: 6.9383e-04
#
# Epoch 00059: val_loss did not improve from 0.00063
# Epoch 60/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.2952e-04 - val_loss: 6.4033e-04
#
# Epoch 00060: val_loss did not improve from 0.00063
# Epoch 61/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.2962e-04 - val_loss: 6.4115e-04
#
# Epoch 00061: val_loss did not improve from 0.00063
# Epoch 62/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.2756e-04 - val_loss: 6.7092e-04
#
# Epoch 00062: val_loss did not improve from 0.00063
# Epoch 63/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.2430e-04 - val_loss: 6.4537e-04
#
# Epoch 00063: val_loss did not improve from 0.00063
# Epoch 64/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 1.2434e-04 - val_loss: 6.7343e-04
#
# Epoch 00064: val_loss did not improve from 0.00063
# Epoch 65/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 1.2472e-04 - val_loss: 6.5619e-04
#
# Epoch 00065: val_loss did not improve from 0.00063
# Epoch 66/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.2385e-04 - val_loss: 6.6166e-04
#
# Epoch 00066: val_loss did not improve from 0.00063
# Epoch 67/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 1.1954e-04 - val_loss: 6.5519e-04
#
# Epoch 00067: val_loss did not improve from 0.00063
# Epoch 68/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 1.1791e-04 - val_loss: 6.4702e-04
#
# Epoch 00068: val_loss did not improve from 0.00063
# Epoch 69/150
# 3424/3424 [==============================] - 1s 172us/step - loss: 1.1717e-04 - val_loss: 6.4149e-04
#
# Epoch 00069: val_loss did not improve from 0.00063
# Epoch 70/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 1.1792e-04 - val_loss: 6.2513e-04
#
# Epoch 00070: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 71/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.1444e-04 - val_loss: 6.3586e-04
#
# Epoch 00071: val_loss did not improve from 0.00063
# Epoch 72/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.1377e-04 - val_loss: 6.3377e-04
#
# Epoch 00072: val_loss did not improve from 0.00063
# Epoch 73/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.1297e-04 - val_loss: 6.2909e-04
#
# Epoch 00073: val_loss did not improve from 0.00063
# Epoch 74/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 1.1014e-04 - val_loss: 6.3452e-04
#
# Epoch 00074: val_loss did not improve from 0.00063
# Epoch 75/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 1.1072e-04 - val_loss: 6.5932e-04
#
# Epoch 00075: val_loss did not improve from 0.00063
# Epoch 76/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.1195e-04 - val_loss: 6.2682e-04
#
# Epoch 00076: val_loss did not improve from 0.00063
# Epoch 77/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.1097e-04 - val_loss: 6.4118e-04
#
# Epoch 00077: val_loss did not improve from 0.00063
# Epoch 78/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 1.1069e-04 - val_loss: 6.4533e-04
#
# Epoch 00078: val_loss did not improve from 0.00063
# Epoch 79/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.0747e-04 - val_loss: 6.6890e-04
#
# Epoch 00079: val_loss did not improve from 0.00063
# Epoch 80/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.0733e-04 - val_loss: 6.3301e-04
#
# Epoch 00080: val_loss did not improve from 0.00063
# Epoch 81/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.0700e-04 - val_loss: 6.2110e-04
#
# Epoch 00081: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 82/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.0814e-04 - val_loss: 6.4251e-04
#
# Epoch 00082: val_loss did not improve from 0.00062
# Epoch 83/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.0552e-04 - val_loss: 6.4662e-04
#
# Epoch 00083: val_loss did not improve from 0.00062
# Epoch 84/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.0416e-04 - val_loss: 6.7443e-04
#
# Epoch 00084: val_loss did not improve from 0.00062
# Epoch 85/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.0214e-04 - val_loss: 6.2922e-04
#
# Epoch 00085: val_loss did not improve from 0.00062
# Epoch 86/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 1.0455e-04 - val_loss: 6.4177e-04
#
# Epoch 00086: val_loss did not improve from 0.00062
# Epoch 87/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 1.0323e-04 - val_loss: 6.3991e-04
#
# Epoch 00087: val_loss did not improve from 0.00062
# Epoch 88/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0376e-04 - val_loss: 6.3743e-04
#
# Epoch 00088: val_loss did not improve from 0.00062
# Epoch 89/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 1.0119e-04 - val_loss: 6.4934e-04
#
# Epoch 00089: val_loss did not improve from 0.00062
# Epoch 90/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 1.0378e-04 - val_loss: 6.5180e-04
#
# Epoch 00090: val_loss did not improve from 0.00062
# Epoch 91/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 1.0248e-04 - val_loss: 6.1565e-04
#
# Epoch 00091: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 92/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 9.9679e-05 - val_loss: 6.4688e-04
#
# Epoch 00092: val_loss did not improve from 0.00062
# Epoch 93/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 9.8671e-05 - val_loss: 6.3375e-04
#
# Epoch 00093: val_loss did not improve from 0.00062
# Epoch 94/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.6930e-05 - val_loss: 6.4174e-04
#
# Epoch 00094: val_loss did not improve from 0.00062
# Epoch 95/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 9.6920e-05 - val_loss: 6.5527e-04
#
# Epoch 00095: val_loss did not improve from 0.00062
# Epoch 96/150
# 3424/3424 [==============================] - 1s 168us/step - loss: 1.0001e-04 - val_loss: 6.5460e-04
#
# Epoch 00096: val_loss did not improve from 0.00062
# Epoch 97/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.7355e-05 - val_loss: 6.5286e-04
#
# Epoch 00097: val_loss did not improve from 0.00062
# Epoch 98/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 9.8422e-05 - val_loss: 6.5394e-04
#
# Epoch 00098: val_loss did not improve from 0.00062
# Epoch 99/150
# 3424/3424 [==============================] - 1s 175us/step - loss: 9.4517e-05 - val_loss: 6.4017e-04
#
# Epoch 00099: val_loss did not improve from 0.00062
# Epoch 100/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.4072e-05 - val_loss: 6.4397e-04
#
# Epoch 00100: val_loss did not improve from 0.00062
# Epoch 101/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 9.4400e-05 - val_loss: 6.6101e-04
#
# Epoch 00101: val_loss did not improve from 0.00062
# Epoch 102/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 9.2914e-05 - val_loss: 6.3365e-04
#
# Epoch 00102: val_loss did not improve from 0.00062
# Epoch 103/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 9.2252e-05 - val_loss: 6.3412e-04
#
# Epoch 00103: val_loss did not improve from 0.00062
# Epoch 104/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 9.3945e-05 - val_loss: 6.4244e-04
#
# Epoch 00104: val_loss did not improve from 0.00062
# Epoch 105/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.2678e-05 - val_loss: 6.3953e-04
#
# Epoch 00105: val_loss did not improve from 0.00062
# Epoch 106/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.2700e-05 - val_loss: 6.4705e-04
#
# Epoch 00106: val_loss did not improve from 0.00062
# Epoch 107/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 9.1950e-05 - val_loss: 6.1803e-04
#
# Epoch 00107: val_loss did not improve from 0.00062
# Epoch 108/150
# 3424/3424 [==============================] - 1s 171us/step - loss: 9.1717e-05 - val_loss: 6.6975e-04
#
# Epoch 00108: val_loss did not improve from 0.00062
# Epoch 109/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.1218e-05 - val_loss: 6.4833e-04
#
# Epoch 00109: val_loss did not improve from 0.00062
# Epoch 110/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 9.1639e-05 - val_loss: 6.3464e-04
#
# Epoch 00110: val_loss did not improve from 0.00062
# Epoch 111/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.1210e-05 - val_loss: 6.5584e-04
#
# Epoch 00111: val_loss did not improve from 0.00062
# Epoch 112/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 8.9331e-05 - val_loss: 6.5655e-04
#
# Epoch 00112: val_loss did not improve from 0.00062
# Epoch 113/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.8747e-05 - val_loss: 6.4427e-04
#
# Epoch 00113: val_loss did not improve from 0.00062
# Epoch 114/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 9.0552e-05 - val_loss: 6.4772e-04
#
# Epoch 00114: val_loss did not improve from 0.00062
# Epoch 115/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.9153e-05 - val_loss: 6.3772e-04
#
# Epoch 00115: val_loss did not improve from 0.00062
# Epoch 116/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 9.0723e-05 - val_loss: 6.3768e-04
#
# Epoch 00116: val_loss did not improve from 0.00062
# Epoch 117/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 8.7076e-05 - val_loss: 6.6908e-04
#
# Epoch 00117: val_loss did not improve from 0.00062
# Epoch 118/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.9441e-05 - val_loss: 6.4359e-04
#
# Epoch 00118: val_loss did not improve from 0.00062
# Epoch 119/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 8.6882e-05 - val_loss: 6.3656e-04
#
# Epoch 00119: val_loss did not improve from 0.00062
# Epoch 120/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.6355e-05 - val_loss: 6.4748e-04
#
# Epoch 00120: val_loss did not improve from 0.00062
# Epoch 121/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.9550e-05 - val_loss: 6.4076e-04
#
# Epoch 00121: val_loss did not improve from 0.00062
# Epoch 122/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.4500e-05 - val_loss: 6.2574e-04
#
# Epoch 00122: val_loss did not improve from 0.00062
# Epoch 123/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.7760e-05 - val_loss: 6.2840e-04
#
# Epoch 00123: val_loss did not improve from 0.00062
# Epoch 124/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.6383e-05 - val_loss: 6.3181e-04
#
# Epoch 00124: val_loss did not improve from 0.00062
# Epoch 125/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.5769e-05 - val_loss: 6.4720e-04
#
# Epoch 00125: val_loss did not improve from 0.00062
# Epoch 126/150
# 3424/3424 [==============================] - 1s 162us/step - loss: 8.4655e-05 - val_loss: 6.2990e-04
#
# Epoch 00126: val_loss did not improve from 0.00062
# Epoch 127/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 8.6082e-05 - val_loss: 6.2177e-04
#
# Epoch 00127: val_loss did not improve from 0.00062
# Epoch 128/150
# 3424/3424 [==============================] - 1s 170us/step - loss: 8.6884e-05 - val_loss: 6.2909e-04
#
# Epoch 00128: val_loss did not improve from 0.00062
# Epoch 129/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 8.5713e-05 - val_loss: 6.5005e-04
#
# Epoch 00129: val_loss did not improve from 0.00062
# Epoch 130/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.4257e-05 - val_loss: 6.3469e-04
#
# Epoch 00130: val_loss did not improve from 0.00062
# Epoch 131/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.5127e-05 - val_loss: 6.4919e-04
#
# Epoch 00131: val_loss did not improve from 0.00062
# Epoch 132/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.6413e-05 - val_loss: 6.4952e-04
#
# Epoch 00132: val_loss did not improve from 0.00062
# Epoch 133/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.2127e-05 - val_loss: 6.3695e-04
#
# Epoch 00133: val_loss did not improve from 0.00062
# Epoch 134/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.3934e-05 - val_loss: 6.3640e-04
#
# Epoch 00134: val_loss did not improve from 0.00062
# Epoch 135/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.3526e-05 - val_loss: 6.3792e-04
#
# Epoch 00135: val_loss did not improve from 0.00062
# Epoch 136/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.1879e-05 - val_loss: 6.5008e-04
#
# Epoch 00136: val_loss did not improve from 0.00062
# Epoch 137/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.2280e-05 - val_loss: 6.4906e-04
#
# Epoch 00137: val_loss did not improve from 0.00062
# Epoch 138/150
# 3424/3424 [==============================] - 1s 161us/step - loss: 8.2882e-05 - val_loss: 6.5516e-04
#
# Epoch 00138: val_loss did not improve from 0.00062
# Epoch 139/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.3292e-05 - val_loss: 6.2755e-04
#
# Epoch 00139: val_loss did not improve from 0.00062
# Epoch 140/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.1610e-05 - val_loss: 6.5549e-04
#
# Epoch 00140: val_loss did not improve from 0.00062
# Epoch 141/150
# 3424/3424 [==============================] - 1s 166us/step - loss: 8.0880e-05 - val_loss: 6.4812e-04
#
# Epoch 00141: val_loss did not improve from 0.00062
# Epoch 142/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 8.0655e-05 - val_loss: 6.4140e-04
#
# Epoch 00142: val_loss did not improve from 0.00062
# Epoch 143/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 7.9899e-05 - val_loss: 6.3351e-04
#
# Epoch 00143: val_loss did not improve from 0.00062
# Epoch 144/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.0271e-05 - val_loss: 6.3936e-04
#
# Epoch 00144: val_loss did not improve from 0.00062
# Epoch 145/150
# 3424/3424 [==============================] - 1s 164us/step - loss: 8.2223e-05 - val_loss: 6.6742e-04
#
# Epoch 00145: val_loss did not improve from 0.00062
# Epoch 146/150
# 3424/3424 [==============================] - 1s 169us/step - loss: 8.2501e-05 - val_loss: 6.5886e-04
#
# Epoch 00146: val_loss did not improve from 0.00062
# Epoch 147/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.0851e-05 - val_loss: 6.4411e-04
#
# Epoch 00147: val_loss did not improve from 0.00062
# Epoch 148/150
# 3424/3424 [==============================] - 1s 167us/step - loss: 8.2723e-05 - val_loss: 6.7780e-04
#
# Epoch 00148: val_loss did not improve from 0.00062
# Epoch 149/150
# 3424/3424 [==============================] - 1s 163us/step - loss: 8.2395e-05 - val_loss: 6.4679e-04
#
# Epoch 00149: val_loss did not improve from 0.00062
# Epoch 150/150
# 3424/3424 [==============================] - 1s 165us/step - loss: 8.1988e-05 - val_loss: 6.4577e-04
#
# Epoch 00150: val_loss did not improve from 0.00062

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
